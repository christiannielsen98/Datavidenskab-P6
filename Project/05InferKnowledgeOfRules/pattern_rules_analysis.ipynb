# %%
import pandas as pd
import plotly.express as px
import re
import datetime
import numpy as np
import json
from Project.Database import Db

# %%
level1_json = json.load(
    open(Db.get_project_path("Project/04TPMAlgorithm/TPM/output/Experiment_minsup0.14_minconf_0.5/level1.json")))

# %%
level2_json = json.load(
    open(Db.get_project_path("Project/04TPMAlgorithm/TPM/output/Experiment_minsup0.14_minconf_0.5/level2.json")))

# %%
level3_json = json.load(
    open(Db.get_project_path("Project/04TPMAlgorithm/TPM/output/Experiment_minsup0.14_minconf_0.5/level3.json")))

# %%
meta = Db.load_data(meta=True, consumption=False, hourly=False)

# %%
def json_to_dataframe(json_file):
    if "," in json_file[0]["name_node"]:
        level_df = pd.DataFrame(columns=["pattern","supp","conf", "time"])
        for i in json_file:
            for j in i["patterns"]:
                level_df.loc[level_df.shape[0]] = j
    else:
        level_df = pd.DataFrame(columns=["name_node","supp","conf"])
        for i in json_file:
            level_df.loc[level_df.shape[0]] = i
    return level_df

# %%
level2_df = json_to_dataframe(level2_json)

# %%
level3_df = json_to_dataframe(level3_json)
level3_df
# Out:
#                                                 pattern      supp      conf  \
# 0     Load_StatusMBALights->Load_StatusMBALights*Loa...  0.698630  0.704420
# 1     Load_StatusMBALights->Load_StatusMBALights*Loa...  0.701370  0.707182
# 2     Load_StatusMBALights->Load_StatusMBALights*Loa...  0.701370  0.701370
# 3     Load_StatusMBALights->Load_StatusMBALights*Loa...  0.701370  0.707182
# 4     Load_StatusMBALights->Load_StatusMBALights*Loa...  0.701370  0.707182
# ...                                                 ...       ...       ...
# 5086  Load_StatusPlugLoadHeatingPad>Load_StatusMBALi...  0.701370  0.707182
# 5087  Load_StatusPlugLoadHeatingPad>Load_StatusMBALi...  0.701370  0.701370
# 5088  Load_StatusPlugLoadHeatingPad->Load_StatusSens...  0.698630  0.704420
# 5089  Load_StatusApplianceOven>Load_StatusPlugLoadVi...  0.276712  0.651613
# 5090  Load_StatusClothesWasher|Load_StatusPlugLoadLR...  0.268493  0.593939
#
#                                                    time
# 0     {'281': [[['2014-04-08 05:58:53', '2014-04-08 ...
# 1     {'281': [[['2014-04-08 05:58:53', '2014-04-08 ...
# 2     {'281': [[['2014-04-08 05:58:53', '2014-04-08 ...
# 3     {'281': [[['2014-04-08 05:58:53', '2014-04-08 ...
# 4     {'281': [[['2014-04-08 05:58:53', '2014-04-08 ...
# ...                                                 ...
# 5086  {'281': [[['2014-04-08 21:58:52', '2014-04-08 ...
# 5087  {'281': [[['2014-04-08 21:58:52', '2014-04-08 ...
# 5088  {'281': [[['2014-04-08 21:58:52', '2014-04-08 ...
# 5089  {'131': [[['2013-11-09 08:15:00', '2013-11-09 ...
# 5090  {'131': [[['2013-11-09 14:30:59', '2013-11-09 ...
#
# [5091 rows x 4 columns]

# %%
level3_df_follow_restricted = level3_df.loc[level3_df['pattern'].str.findall('-').map(len) <= 1]

# %%
index_list = []
for index, row in level3_df_follow_restricted.iterrows():
    tmp_floor_list = []
    for col in re.findall('[\w_]+', row['pattern']):
        try:
            tmp_floor_list.append(meta.loc[col, 'Measurement_Floor'])
        except:
            continue
        if '1stFloor' in tmp_floor_list and '2ndFloor' in tmp_floor_list:
            print(re.findall('[\w_]+', row['pattern']))
# Out:
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBlender', 'Load_StatusMBALights', 'Load_StatusPlugLoadBlender']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBlender', 'Load_StatusMBALights', 'Load_StatusPlugLoadBlender']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBlender', 'Load_StatusMBALights', 'Load_StatusPlugLoadBlender']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBlender', 'Load_StatusMBALights', 'Load_StatusPlugLoadBlender']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBlender', 'Load_StatusMBALights', 'Load_StatusPlugLoadBlender']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToasterOven', 'Load_StatusMBALights', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToasterOven', 'Load_StatusMBALights', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToasterOven', 'Load_StatusMBALights', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToasterOven', 'Load_StatusMBALights', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToasterOven', 'Load_StatusMBALights', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'MasterBedroomLights', 'Load_StatusMBALights', 'MasterBedroomLights']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'MasterBedroomLights', 'Load_StatusMBALights', 'MasterBedroomLights']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'MasterBedroomLights', 'Load_StatusMBALights', 'MasterBedroomLights']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToaster', 'Load_StatusMBALights', 'Load_StatusPlugLoadToaster']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToaster', 'Load_StatusMBALights', 'Load_StatusPlugLoadToaster']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToaster', 'Load_StatusMBALights', 'Load_StatusPlugLoadToaster']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToaster', 'Load_StatusMBALights', 'Load_StatusPlugLoadToaster']
# ['Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToaster', 'Load_StatusMBALights', 'Load_StatusPlugLoadToaster']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadBlender', 'Load_StatusPlugLoadBlender', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadBlender', 'Load_StatusPlugLoadBlender', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadBlender', 'Load_StatusPlugLoadBlender', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadBlender', 'Load_StatusPlugLoadBlender', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadBlender', 'Load_StatusPlugLoadBlender', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadMBRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadMBRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadMBRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadMBRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadMBRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadToasterOven', 'Load_StatusMBALights', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadToasterOven', 'Load_StatusMBALights', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadToasterOven', 'Load_StatusMBALights', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadToasterOven', 'Load_StatusMBALights', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadToasterOven', 'Load_StatusMBALights', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'MasterBedroomLights', 'Load_StatusMBALights', 'MasterBedroomLights']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'MasterBedroomLights', 'Load_StatusMBALights', 'MasterBedroomLights']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'MasterBedroomLights', 'Load_StatusMBALights', 'MasterBedroomLights']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadToaster', 'Load_StatusMBALights', 'Load_StatusPlugLoadToaster']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadToaster', 'Load_StatusMBALights', 'Load_StatusPlugLoadToaster']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadToaster', 'Load_StatusMBALights', 'Load_StatusPlugLoadToaster']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadToaster', 'Load_StatusMBALights', 'Load_StatusPlugLoadToaster']
# ['Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadToaster', 'Load_StatusMBALights', 'Load_StatusPlugLoadToaster']
# ['Load_StatusMBALights', 'Load_StatusBA1Lights', 'Load_StatusBA1Lights', 'Load_StatusApplianceCooktop', 'Load_StatusMBALights', 'Load_StatusApplianceCooktop']
# ['Load_StatusMBALights', 'Load_StatusBA1Lights', 'Load_StatusBA1Lights', 'Load_StatusApplianceCooktop', 'Load_StatusMBALights', 'Load_StatusApplianceCooktop']
# ['Load_StatusMBALights', 'Load_StatusBA1Lights', 'Load_StatusBA1Lights', 'Load_StatusApplianceCooktop', 'Load_StatusMBALights', 'Load_StatusApplianceCooktop']
# ['Load_StatusMBALights', 'Load_StatusBA1Lights', 'Load_StatusBA1Lights', 'Load_StatusApplianceCooktop', 'Load_StatusMBALights', 'Load_StatusApplianceCooktop']
# ['Load_StatusMBALights', 'Load_StatusBA1Lights', 'Load_StatusBA1Lights', 'Load_StatusApplianceCooktop', 'Load_StatusMBALights', 'Load_StatusApplianceCooktop']
# ['Load_StatusMBALights', 'Load_StatusBA1Lights', 'Load_StatusBA1Lights', 'Load_StatusApplianceRangeHood', 'Load_StatusMBALights', 'Load_StatusApplianceRangeHood']
# ['Load_StatusMBALights', 'Load_StatusBA1Lights', 'Load_StatusBA1Lights', 'Load_StatusApplianceRangeHood', 'Load_StatusMBALights', 'Load_StatusApplianceRangeHood']
# ['Load_StatusMBALights', 'Load_StatusBA1Lights', 'Load_StatusBA1Lights', 'Load_StatusApplianceRangeHood', 'Load_StatusMBALights', 'Load_StatusApplianceRangeHood']
# ['Load_StatusMBALights', 'Load_StatusBA1Lights', 'Load_StatusBA1Lights', 'Load_StatusApplianceRangeHood', 'Load_StatusMBALights', 'Load_StatusApplianceRangeHood']
# ['Load_StatusMBALights', 'Load_StatusBA1Lights', 'Load_StatusBA1Lights', 'Load_StatusApplianceRangeHood', 'Load_StatusMBALights', 'Load_StatusApplianceRangeHood']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'MasterBedroomLights', 'Load_StatusMBALights', 'MasterBedroomLights']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'MasterBedroomLights', 'Load_StatusMBALights', 'MasterBedroomLights']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'MasterBedroomLights', 'Load_StatusMBALights', 'MasterBedroomLights']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusBA2Lights', 'Load_StatusMBALights', 'Load_StatusBA2Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusBA2Lights', 'Load_StatusMBALights', 'Load_StatusBA2Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusBA2Lights', 'Load_StatusMBALights', 'Load_StatusBA2Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusBA2Lights', 'Load_StatusMBALights', 'Load_StatusBA2Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusBA2Lights', 'Load_StatusMBALights', 'Load_StatusBA2Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusPlugLoadLRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusPlugLoadLRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusPlugLoadLRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusPlugLoadLRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusPlugLoadLRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusBA1Lights', 'Load_StatusMBALights', 'Load_StatusBA1Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusBA1Lights', 'Load_StatusMBALights', 'Load_StatusBA1Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusBA1Lights', 'Load_StatusMBALights', 'Load_StatusBA1Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusBA1Lights', 'Load_StatusMBALights', 'Load_StatusBA1Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusBA1Lights', 'Load_StatusMBALights', 'Load_StatusBA1Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceRangeHood', 'Load_StatusMBALights', 'Load_StatusApplianceRangeHood']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceRangeHood', 'Load_StatusMBALights', 'Load_StatusApplianceRangeHood']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceRangeHood', 'Load_StatusMBALights', 'Load_StatusApplianceRangeHood']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceRangeHood', 'Load_StatusMBALights', 'Load_StatusApplianceRangeHood']
# ['Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceCooktop', 'Load_StatusApplianceRangeHood', 'Load_StatusMBALights', 'Load_StatusApplianceRangeHood']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'MasterBedroomLights', 'Load_StatusMBALights', 'MasterBedroomLights']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'MasterBedroomLights', 'Load_StatusMBALights', 'MasterBedroomLights']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'MasterBedroomLights', 'Load_StatusMBALights', 'MasterBedroomLights']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'Load_StatusBA2Lights', 'Load_StatusMBALights', 'Load_StatusBA2Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'Load_StatusBA2Lights', 'Load_StatusMBALights', 'Load_StatusBA2Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'Load_StatusBA2Lights', 'Load_StatusMBALights', 'Load_StatusBA2Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'Load_StatusBA2Lights', 'Load_StatusMBALights', 'Load_StatusBA2Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'Load_StatusBA2Lights', 'Load_StatusMBALights', 'Load_StatusBA2Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'Load_StatusPlugLoadLRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'Load_StatusPlugLoadLRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'Load_StatusPlugLoadLRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'Load_StatusPlugLoadLRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'Load_StatusPlugLoadLRTV', 'Load_StatusMBALights', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'Load_StatusBA1Lights', 'Load_StatusMBALights', 'Load_StatusBA1Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'Load_StatusBA1Lights', 'Load_StatusMBALights', 'Load_StatusBA1Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'Load_StatusBA1Lights', 'Load_StatusMBALights', 'Load_StatusBA1Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'Load_StatusBA1Lights', 'Load_StatusMBALights', 'Load_StatusBA1Lights']
# ['Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusApplianceRangeHood', 'Load_StatusBA1Lights', 'Load_StatusMBALights', 'Load_StatusBA1Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadBlender', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBlender']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadBlender', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBlender']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadBlender', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBlender']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadBlender', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBlender']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadBlender', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBlender']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadToasterOven', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadToasterOven', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadToasterOven', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadToasterOven', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadToasterOven', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'MasterBedroomLights', 'Load_StatusSensHeatPrntBDOWN', 'MasterBedroomLights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'MasterBedroomLights', 'Load_StatusSensHeatPrntBDOWN', 'MasterBedroomLights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'MasterBedroomLights', 'Load_StatusSensHeatPrntBDOWN', 'MasterBedroomLights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadToaster', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToaster']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadToaster', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToaster']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadToaster', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToaster']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadToaster', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToaster']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadToaster', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToaster']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBA2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBA2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBA2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBA2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBA2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadLRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadLRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadLRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadLRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadLRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntADOWN']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntADOWN']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntADOWN']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntADOWN']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntADOWN']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBR2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBR2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBR2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBR2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBR2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBR3Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR3Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBR3Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR3Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBR3Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR3Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBR3Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR3Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBR3Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR3Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBA1Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA1Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBA1Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA1Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBA1Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA1Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBA1Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA1Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusBA1Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA1Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusApplianceCooktop']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusApplianceCooktop']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusApplianceCooktop']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusApplianceCooktop']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusApplianceCooktop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusApplianceCooktop']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusApplianceRangeHood']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusApplianceRangeHood']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusApplianceRangeHood']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusApplianceRangeHood']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusApplianceRangeHood', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusApplianceRangeHood']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadBR2Laptop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBR2Laptop']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadBR2Laptop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBR2Laptop']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadBR2Laptop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBR2Laptop']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadBR2Laptop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBR2Laptop']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadBR2Laptop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBR2Laptop']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadBR3Laptop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBR3Laptop']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadBR3Laptop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBR3Laptop']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadBR3Laptop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBR3Laptop']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadBR3Laptop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBR3Laptop']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadBR3Laptop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBR3Laptop']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadDesktopPCMonitor', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadDesktopPCMonitor']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadDesktopPCMonitor', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadDesktopPCMonitor']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadDesktopPCMonitor', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadDesktopPCMonitor']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadDesktopPCMonitor', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadDesktopPCMonitor']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusPlugLoadDesktopPCMonitor', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadDesktopPCMonitor']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights', 'Load_StatusMBALights', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusBA2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusBA2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusBA2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusBA2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusBA2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusBA2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusBR3Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR3Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusBR3Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR3Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusBR3Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR3Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusSensHeatChildAUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildAUP']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusSensHeatChildAUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildAUP']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusSensHeatChildAUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildAUP']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntAUP']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntAUP']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntAUP']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusPlugLoadBR2Laptop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBR2Laptop']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusPlugLoadBR2Laptop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBR2Laptop']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusPlugLoadBR2Laptop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBR2Laptop']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusPlugLoadBR3Laptop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBR3Laptop']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusPlugLoadBR3Laptop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBR3Laptop']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusPlugLoadBR3Laptop', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBR3Laptop']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusPlugLoadFan', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadFan']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusPlugLoadFan', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadFan']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusPlugLoadFan', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadFan']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusPlugLoadHeatingPad', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadHeatingPad']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusPlugLoadHeatingPad', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadHeatingPad']
# ['Load_StatusSensHeatPrntBDOWN', 'KitchenLights', 'KitchenLights', 'Load_StatusPlugLoadHeatingPad', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadHeatingPad']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBlender', 'Load_StatusPlugLoadBlender', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBlender', 'Load_StatusPlugLoadBlender', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadBlender', 'Load_StatusPlugLoadBlender', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusMBALights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusMBALights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadToasterOven', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadToasterOven', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadToasterOven', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadToasterOven', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadToasterOven', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'MasterBedroomLights', 'Load_StatusSensHeatPrntBDOWN', 'MasterBedroomLights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'MasterBedroomLights', 'Load_StatusSensHeatPrntBDOWN', 'MasterBedroomLights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'MasterBedroomLights', 'Load_StatusSensHeatPrntBDOWN', 'MasterBedroomLights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'MasterBedroomLights', 'Load_StatusSensHeatPrntBDOWN', 'MasterBedroomLights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'MasterBedroomLights', 'Load_StatusSensHeatPrntBDOWN', 'MasterBedroomLights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'MasterBedroomLights', 'Load_StatusSensHeatPrntBDOWN', 'MasterBedroomLights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadToaster', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToaster']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadToaster', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToaster']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadToaster', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToaster']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadToaster', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToaster']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadToaster', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadToaster']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusBA2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusBA2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusBA2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusBA2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusBA2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBA2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadLRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadLRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadLRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadLRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadLRTV', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntADOWN']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntADOWN']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntADOWN']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntADOWN']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntADOWN']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatPrntBUP']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusBR2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusBR2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusBR2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR2Lights']
# ['Load_StatusSensHeatPrntBDOWN', 'Load_StatusPlugLoadMBRTV', 'Load_StatusPlugLoadMBRTV', 'Load_StatusBR2Lights', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusBR2Lights']
# ...
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatChildBDOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatChildBDOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatChildBDOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatChildBDOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusPlugLoadBlender', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadBlender']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusPlugLoadBlender', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadBlender']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusPlugLoadBlender', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadBlender']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusPlugLoadToasterOven', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusPlugLoadToasterOven', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusPlugLoadToasterOven', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusPlugLoadToaster', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadToaster']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusPlugLoadToaster', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadToaster']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusPlugLoadToaster', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadToaster']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusPlugLoadLRTV', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusPlugLoadLRTV', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusPlugLoadLRTV', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntADOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntADOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntBUP', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntADOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusDRLights', 'Load_StatusDRLights', 'KitchenLights', 'Load_StatusSensHeatChildBUP', 'KitchenLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusDRLights', 'Load_StatusDRLights', 'KitchenLights', 'Load_StatusSensHeatChildBUP', 'KitchenLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusDRLights', 'Load_StatusDRLights', 'KitchenLights', 'Load_StatusSensHeatChildBUP', 'KitchenLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusDRLights', 'Load_StatusDRLights', 'Load_StatusSensHeatChildADOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatChildADOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusDRLights', 'Load_StatusDRLights', 'Load_StatusSensHeatChildADOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatChildADOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusDRLights', 'Load_StatusDRLights', 'Load_StatusSensHeatChildADOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatChildADOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusDRLights', 'Load_StatusDRLights', 'Load_StatusSensHeatChildADOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatChildADOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusDRLights', 'Load_StatusDRLights', 'Load_StatusSensHeatChildADOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatChildADOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusDRLights', 'Load_StatusDRLights', 'Load_StatusSensHeatChildBDOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatChildBDOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusDRLights', 'Load_StatusDRLights', 'Load_StatusSensHeatChildBDOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatChildBDOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusDRLights', 'Load_StatusDRLights', 'Load_StatusSensHeatChildBDOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatChildBDOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusDRLights', 'Load_StatusDRLights', 'Load_StatusSensHeatChildBDOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatChildBDOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusDRLights', 'Load_StatusDRLights', 'Load_StatusSensHeatChildBDOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatChildBDOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusDRLights', 'Load_StatusDRLights', 'LivingRoomLights', 'Load_StatusSensHeatChildBUP', 'LivingRoomLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusDRLights', 'Load_StatusDRLights', 'LivingRoomLights', 'Load_StatusSensHeatChildBUP', 'LivingRoomLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusDRLights', 'Load_StatusDRLights', 'LivingRoomLights', 'Load_StatusSensHeatChildBUP', 'LivingRoomLights']
# ['Load_StatusSensHeatChildBUP', 'LivingRoomLights', 'LivingRoomLights', 'Load_StatusDRLights', 'Load_StatusSensHeatChildBUP', 'Load_StatusDRLights']
# ['Load_StatusSensHeatChildBUP', 'LivingRoomLights', 'LivingRoomLights', 'Load_StatusDRLights', 'Load_StatusSensHeatChildBUP', 'Load_StatusDRLights']
# ['Load_StatusSensHeatChildBUP', 'LivingRoomLights', 'LivingRoomLights', 'Load_StatusDRLights', 'Load_StatusSensHeatChildBUP', 'Load_StatusDRLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntBDOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntBDOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusPlugLoadBlender', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadBlender']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusPlugLoadBlender', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadBlender']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusPlugLoadBlender', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadBlender']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusPlugLoadCoffeeMaker', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCoffeeMaker']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusPlugLoadToasterOven', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusPlugLoadToasterOven', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusPlugLoadToasterOven', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadToasterOven']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusPlugLoadToaster', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadToaster']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusPlugLoadToaster', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadToaster']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusPlugLoadToaster', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadToaster']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusPlugLoadLRTV', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusPlugLoadLRTV', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusPlugLoadLRTV', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadLRTV']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntADOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntADOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntAUP', 'Load_StatusSensHeatPrntADOWN', 'Load_StatusSensHeatChildBUP', 'Load_StatusSensHeatPrntADOWN']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadCanOpener', 'KitchenLights', 'Load_StatusSensHeatChildBUP', 'KitchenLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadCanOpener', 'KitchenLights', 'Load_StatusSensHeatChildBUP', 'KitchenLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadCanOpener', 'KitchenLights', 'Load_StatusSensHeatChildBUP', 'KitchenLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadCanOpener', 'Load_StatusDRLights', 'Load_StatusSensHeatChildBUP', 'Load_StatusDRLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadCanOpener', 'Load_StatusDRLights', 'Load_StatusSensHeatChildBUP', 'Load_StatusDRLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadCanOpener', 'Load_StatusDRLights', 'Load_StatusSensHeatChildBUP', 'Load_StatusDRLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadCanOpener', 'Load_StatusDRLights', 'Load_StatusSensHeatChildBUP', 'Load_StatusDRLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadCanOpener', 'Load_StatusDRLights', 'Load_StatusSensHeatChildBUP', 'Load_StatusDRLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadCanOpener', 'LivingRoomLights', 'Load_StatusSensHeatChildBUP', 'LivingRoomLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadCanOpener', 'LivingRoomLights', 'Load_StatusSensHeatChildBUP', 'LivingRoomLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadCanOpener', 'LivingRoomLights', 'Load_StatusSensHeatChildBUP', 'LivingRoomLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadHandMixer', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadHandMixer']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadHandMixer', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadHandMixer']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadHandMixer', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadHandMixer']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadHandMixer', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadHandMixer']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadCanOpener', 'Load_StatusPlugLoadHandMixer', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadHandMixer']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadHandMixer', 'Load_StatusPlugLoadHandMixer', 'KitchenLights', 'Load_StatusSensHeatChildBUP', 'KitchenLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadHandMixer', 'Load_StatusPlugLoadHandMixer', 'KitchenLights', 'Load_StatusSensHeatChildBUP', 'KitchenLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadHandMixer', 'Load_StatusPlugLoadHandMixer', 'KitchenLights', 'Load_StatusSensHeatChildBUP', 'KitchenLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadHandMixer', 'Load_StatusPlugLoadHandMixer', 'LivingRoomLights', 'Load_StatusSensHeatChildBUP', 'LivingRoomLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadHandMixer', 'Load_StatusPlugLoadHandMixer', 'LivingRoomLights', 'Load_StatusSensHeatChildBUP', 'LivingRoomLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadHandMixer', 'Load_StatusPlugLoadHandMixer', 'LivingRoomLights', 'Load_StatusSensHeatChildBUP', 'LivingRoomLights']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadHandMixer', 'Load_StatusPlugLoadHandMixer', 'Load_StatusPlugLoadCanOpener', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadHandMixer', 'Load_StatusPlugLoadHandMixer', 'Load_StatusPlugLoadCanOpener', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadHandMixer', 'Load_StatusPlugLoadHandMixer', 'Load_StatusPlugLoadCanOpener', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadHandMixer', 'Load_StatusPlugLoadHandMixer', 'Load_StatusPlugLoadCanOpener', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener']
# ['Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadHandMixer', 'Load_StatusPlugLoadHandMixer', 'Load_StatusPlugLoadCanOpener', 'Load_StatusSensHeatChildBUP', 'Load_StatusPlugLoadCanOpener']

# %%
meta.loc[meta.index == "Load_StatusPlugLoadBlender"]
# Out:
#                            Subsystem Measurement_Location     Parameter  \
# Unnamed: 0
# Load_StatusPlugLoadBlender     Loads              Kitchen  Status_OnOff
#
#                                                                   Description  \
# Unnamed: 0
# Load_StatusPlugLoadBlender  Number to indicate whether blender is activate...
#
#                                    Units Aggregation_Method  min_value  \
# Unnamed: 0
# Load_StatusPlugLoadBlender  BinaryStatus            Average      -1.11
#
#                             max_value Measurement_Floor  \
# Unnamed: 0
# Load_StatusPlugLoadBlender        1.0          1stFloor
#
#                                            Load_Match Status_Match  \
# Unnamed: 0
# Load_StatusPlugLoadBlender  Load_KPlugLoadsPowerUsage          NaN
#
#                                          Elec_Match
# Unnamed: 0
# Load_StatusPlugLoadBlender  Elec_PowerPlugsKitRange
